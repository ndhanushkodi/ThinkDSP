# %% [markdown]
# ThinkDSP, by Allen Downey (think-dsp.com)
#
# This notebook contains code examples from Chapter

# %%
from __future__ import print_function, division

import thinkdsp
import thinkplot
import thinkstats2
import math
import numpy
import pandas
import scipy.signal
import matplotlib.pyplot as plt

PI2 = 2 * math.pi

# %precision 3
# %matplotlib inline

# %% [markdown]
# We'll start by exploring the price of BitCoin, which resembles red noise:

# %%
df = pandas.read_csv('coindesk-bpi-USD-close.csv', nrows=1625, parse_dates=[0])
ys = df.Close.values
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-a54d7ff79474> in <module>()
# ----> 1 df = pandas.read_csv('coindesk-bpi-USD-close.csv', nrows=1625, parse_dates=[0])
#       2 ys = df.Close.values
#
# /home/ndhanushkodi/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format)
#     450                     infer_datetime_format=infer_datetime_format)
#     451
# --> 452         return _read(filepath_or_buffer, kwds)
#     453
#     454     parser_f.__name__ = name
#
# /home/ndhanushkodi/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _read(filepath_or_buffer, kwds)
#     232
#     233     # Create the parser.
# --> 234     parser = TextFileReader(filepath_or_buffer, **kwds)
#     235
#     236     if (nrows is not None) and (chunksize is not None):
#
# /home/ndhanushkodi/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, f, engine, **kwds)
#     540             self.options['has_index_names'] = kwds['has_index_names']
#     541
# --> 542         self._make_engine(self.engine)
#     543
#     544     def _get_options_with_defaults(self, engine):
#
# /home/ndhanushkodi/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in _make_engine(self, engine)
#     677     def _make_engine(self, engine='c'):
#     678         if engine == 'c':
# --> 679             self._engine = CParserWrapper(self.f, **self.options)
#     680         else:
#     681             if engine == 'python':
#
# /home/ndhanushkodi/anaconda/lib/python2.7/site-packages/pandas/io/parsers.pyc in __init__(self, src, **kwds)
#    1039         kwds['allow_leading_cols'] = self.index_col is not False
#    1040
# -> 1041         self._reader = _parser.TextReader(src, **kwds)
#    1042
#    1043         # XXX
#
# /home/ndhanushkodi/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader.__cinit__ (pandas/parser.c:3218)()
#
# /home/ndhanushkodi/anaconda/lib/python2.7/site-packages/pandas/parser.so in pandas.parser.TextReader._setup_parser_source (pandas/parser.c:5594)()
#
# IOError: File coindesk-bpi-USD-close.csv does not exist

# %% [markdown]
# Here's what the time series looks like:

# %%
wave = thinkdsp.Wave(ys, framerate=1)
wave.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-081c65dbb1ec> in <module>()
# ----> 1 wave = thinkdsp.Wave(ys, framerate=1)
#       2 wave.plot()
#
# NameError: name 'ys' is not defined

# %% [markdown]
# And here's the spectrum on a log-log scale.

# %%
spectrum = wave.make_spectrum()
spectrum.plot()
thinkplot.config(xscale='log', yscale='log', legend=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-c8d464412cce> in <module>()
# ----> 1 spectrum = wave.make_spectrum()
#       2 spectrum.plot()
#       3 thinkplot.config(xscale='log', yscale='log', legend=False)
#
# NameError: name 'wave' is not defined

# %% [markdown]
# The slope is -1.8, which is similar to red noise (which should have a slope of -2).

# %%
spectrum.estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-dee5406decfc> in <module>()
# ----> 1 spectrum.estimate_slope()
#
# NameError: name 'spectrum' is not defined

# %% [markdown]
# We can use `numpy.diff` to compute the difference between successive elements, which is the daily change.

# %%
diff = numpy.diff(ys)
wave2 = thinkdsp.Wave(diff, framerate=1)
wave2.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1f0f5f554bb9> in <module>()
# ----> 1 diff = numpy.diff(ys)
#       2 wave2 = thinkdsp.Wave(diff, framerate=1)
#       3 wave2.plot()
#
# NameError: name 'ys' is not defined

# %% [markdown]
# And here's the spectrum of the daily changes:

# %%
spectrum2 = wave2.make_spectrum()
spectrum2.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-a8945a5273fd> in <module>()
# ----> 1 spectrum2 = wave2.make_spectrum()
#       2 spectrum2.plot()
#
# NameError: name 'wave2' is not defined

# %% [markdown]
# And here's the spectrum on a log-log scale.

# %%
spectrum2.plot()
thinkplot.config(xscale='log', yscale='log', legend=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-36bc27d332b1> in <module>()
# ----> 1 spectrum2.plot()
#       2 thinkplot.config(xscale='log', yscale='log', legend=False)
#
# NameError: name 'spectrum2' is not defined

# %% [markdown]
# The estimated slope is close to zero, which is consistent with white noise.

# %%
spectrum2.estimate_slope()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-5b4f1720d3e1> in <module>()
# ----> 1 spectrum2.estimate_slope()
#
# NameError: name 'spectrum2' is not defined

# %% [markdown]
# Now let's compare the spectrum of closing price with the spectrum of daily changes; that is, the ratio of the spectrums before and after applying 'numpy.diff':

# %%
amps = spectrum.amps
amps2 = spectrum2.amps

n = min(len(amps), len(amps2))
ratio = amps2[:n] / amps[:n]

thinkplot.plot(ratio)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-6ee7c66e0697> in <module>()
# ----> 1 amps = spectrum.amps
#       2 amps2 = spectrum2.amps
#       3
#       4 n = min(len(amps), len(amps2))
#       5 ratio = amps2[:n] / amps[:n]
#
# NameError: name 'spectrum' is not defined

# %% [markdown]
# We can think the diff operation as convolution with a difference window:

# %%
window = numpy.array([1.0, -1.0])
plt.plot(window)

# %% [markdown]
# And we can use `scipy.signal.convolve` to compute it:

# %%
ys = scipy.signal.convolve(wave.ys, window, mode='valid')
diff = thinkdsp.Wave(ys, framerate=1)
diff.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-131efe7fd3de> in <module>()
# ----> 1 ys = scipy.signal.convolve(wave.ys, window, mode='valid')
#       2 diff = thinkdsp.Wave(ys, framerate=1)
#       3 diff.plot()
#
# NameError: name 'wave' is not defined

# %% [markdown]
# Or you can compute the same thing by computing the difference filter, which is the DFT of the difference window, and they multiplying in the frequency domain.

# %%
def zero_pad(array, n):
    res = numpy.zeros(n)
    res[:len(array)] = array
    return res

# %% [markdown]
# Here are two windows that approximate the first derivative:

# %%
window = numpy.array([1.0, -1.0])
window2 = numpy.array([-1, 4, -3]) / 2.0

padded = zero_pad(window, len(wave))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-ce18ee1d6120> in <module>()
#       2 window2 = numpy.array([-1, 4, -3]) / 2.0
#       3
# ----> 4 padded = zero_pad(window, len(wave))
#
# NameError: name 'wave' is not defined

# %% [markdown]
# And here's what the corresponding filter looks like:

# %%
fft_window = numpy.fft.rfft(padded)
thinkplot.plot(abs(fft_window))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-37da22f59d64> in <module>()
# ----> 1 fft_window = numpy.fft.rfft(padded)
#       2 thinkplot.plot(abs(fft_window))
#
# NameError: name 'padded' is not defined

# %% [markdown]
# Now here's the filter again, superimposed on the ratios we computed earlier:

# %%
thinkplot.plot(ratio, color='gray')
thinkplot.plot(abs(fft_window))
thinkplot.config(ylim=[0, 4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0d9a52b560a8> in <module>()
# ----> 1 thinkplot.plot(ratio, color='gray')
#       2 thinkplot.plot(abs(fft_window))
#       3 thinkplot.config(ylim=[0, 4])
#
# NameError: name 'ratio' is not defined

# %% [markdown]
# The difference filter has this shape because it is an approximation of differentiation, and the filter for differentiation is proportional to $f$.  Specifically, each complex component is multiplied by $2 \pi i f$.  So we can compute a numerical derivative by applying this filter in the frequency domain:

# %%
spectrum3 = wave.make_spectrum()
i = complex(0, 1)
filtr = PI2 * i * spectrum3.fs
spectrum3.hs *= filtr
spectrum3.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-a43f17abdfa7> in <module>()
# ----> 1 spectrum3 = wave.make_spectrum()
#       2 i = complex(0, 1)
#       3 filtr = PI2 * i * spectrum3.fs
#       4 spectrum3.hs *= filtr
#       5 spectrum3.plot()
#
# NameError: name 'wave' is not defined

# %% [markdown]
# The results are similar, with some differences due to (1) the difference window is only a coarse approximation of the derivative, especially at higher frequencies, and (2) the spectral derivative is based on the assumption that the signal is periodic, so the behavior at the beginning and end is different.

# %%
wave3 = spectrum3.make_wave()
wave2.plot(color='0.7')
wave3.plot()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-35900c05f719> in <module>()
# ----> 1 wave3 = spectrum3.make_wave()
#       2 wave2.plot(color='0.7')
#       3 wave3.plot()
#
# NameError: name 'spectrum3' is not defined

# %% [markdown]
# Here's the difference between the derivative filter and the difference filter:

# %%
amps = spectrum.amps
amps3 = spectrum3.amps
ratio3 = amps3 / amps
thinkplot.plot(abs(fft_window))
thinkplot.plot(ratio3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6519ef0ca3b3> in <module>()
# ----> 1 amps = spectrum.amps
#       2 amps3 = spectrum3.amps
#       3 ratio3 = amps3 / amps
#       4 thinkplot.plot(abs(fft_window))
#       5 thinkplot.plot(ratio3)
#
# NameError: name 'spectrum' is not defined

# %% [markdown]
# The next topic is the use of impulse response for system characterization.  We start with a recording of a gunshot:

# %%
response = thinkdsp.read_wave('180961__kleeb__gunshots.wav')
response = response.segment(start=0.26, duration=5.0)
response.normalize()
response.plot()
thinkplot.config(ylim=[-1.05, 1.05])
# Out:
# /home/ndhanushkodi/anaconda/lib/python2.7/site-packages/matplotlib/axes/_axes.py:475: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# Here's what it sounds like:

# %%
response.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# The recording is the impulse response of the system (the room and recording equipment).   The DFT of the impulse response is the transfer function:

# %%
transfer = response.make_spectrum()
transfer.plot()

# %% [markdown]
# Here's the transfer function on a log-log scale:

# %%
transfer.plot()
thinkplot.config(xscale='log', yscale='log')

# %% [markdown]
# Now we can simulate what a recording would sound like if it were played in the same room and recorded in the same way.  Here's the violin recording we have used before:

# %%
violin = thinkdsp.read_wave('92002__jcveliz__violin-origional.wav')
violin.ys = violin.ys[:len(response)]
violin.normalize()
violin.plot()
thinkplot.config(ylim=[-1.05, 1.05])

# %% [markdown]
# Here's what it sounds like before transformation:

# %%
violin.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# Now we compute the DFT of the violin recording.

# %%
spectrum = violin.make_spectrum()

# %% [markdown]
# I trimmed the violin recording to the same length as the impulse response:

# %%
len(spectrum.hs), len(transfer.hs)
# Out:
# (51589, 51589)

# %% [markdown]
# We we can multiply in the frequency domain and the transform back to the time domain.

# %%
output = (spectrum * transfer).make_wave()
output.normalize()

# %% [markdown]
# Here'a  comparison of the original and transformed recordings:

# %%
violin.plot()
output.plot()

# %% [markdown]
# And here's what it sounds like:

# %%
output.make_audio()
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# To understand how that worked, you can think about the input signal as a series of impulses, and the output as the sume of shifted, scaled versions of the impulse response.

# %%
def shifted_scaled(wave, shift, factor):
    res = wave.copy()
    res.shift(shift)
    res.scale(factor)
    return res

# %% [markdown]
# Here' what it would sound like if we fired a big gun followed by a small gun:

# %%
dt = 1
shift = dt * response.framerate
factor = 0.5

response2 = response + shifted_scaled(response, shift, factor)
response2.plot()
thinkplot.config(xlabel='time (s)', ylabel='amplitude', ylim=[-1.05, 1.05])

# %% [markdown]
# Two gunshots:

# %%
response2.make_audio()

# %% [markdown]
# Here's what it sounds like if we fire 100 guns at a rate of 441 gunshots per second:

# %%
total = 0
for j in range(100):
    total += shifted_scaled(response, j*100, 1.0)
total.normalize()

# %%
total.make_audio()

# %% [markdown]
# The result has a fundamental frequency at 441, with additional harmonics.

# %%
total.make_spectrum().plot(high=8000)

# %% [markdown]
# Now let's do the same thing with a sawtooth signal:

# %%
sawtooth = thinkdsp.SawtoothSignal(freq=410).make_wave(duration=0.2, framerate=response.framerate)
sawtooth.plot()
thinkplot.config(xlabel='time (s)', ylabel='amplitude', ylim=[-1.05, 1.05])

# %% [markdown]
# Here's what it sounds like:

# %%
sawtooth.make_audio()

# %% [markdown]
# And here's what we get if we use the sawtooth to generate shifted, scaled versions of the impulse response:

# %%
total = 0
for j, y in enumerate(sawtooth.ys):
    total += shifted_scaled(response, j, y)
total.normalize()

# %% [markdown]
# The result is a simulation of what the sawtooth signal would sound like if it was recorded in the room where the gunshot was recorded:

# %%
total.plot()
thinkplot.config(xlabel='time (s)', ylabel='amplitude', ylim=[-1.05, 1.05])

# %% [markdown]
# And here's what it sounds like:

# %%
total.make_audio()

# %% [markdown]
# To me it sounds a bit like a car horn in a garage.
#
# And here's the spectrum:

# %%
total.make_spectrum().plot(high=8000)

# %% [markdown]
# Here's a comparison before and after convolution:

# %%
sawtooth.make_spectrum().plot(high=500, color='0.7')

segment = total.segment(duration=0.2)
segment.make_spectrum().plot(high=1000)
thinkplot.config(xlabel='frequency (Hz)', ylabel='amplitude')

# %% [markdown]
# Now that we recognize this operation as convolution, we can compute it by multiplying the signals (which performs convolution):

# %%
convolved = sawtooth * response
convolved.normalize()
convolved.make_audio()

# %% [markdown]
# And we can do the same thing with the violin recording:

# %%
convolved2 = violin * response
convolved2.normalize()
convolved2.make_audio()

# %% [markdown]
# To understand why the impulse response is sufficient to characterize a system, it is informative to look at the DFT of an impulse:

# %%
impulse = numpy.zeros(8)
impulse[0] = 1
print(impulse)

# %% [markdown]
# The DFT of an impulse is all ones, which means that the impulse contains equal energy at all frequencies.  So testing a system with an impulse is like testing it will all frequency components at the same time:

# %%
spectrum = numpy.fft.fft(impulse)
print(spectrum)

# %% [markdown]
# You might notice something about the impulse and its DFT:

# %%
numpy.sum(numpy.absolute(impulse)**2)

# %%
numpy.sum(numpy.absolute(spectrum)**2)

# %% [markdown]
# In general, the total magnitue of DFT(y) is N times the total magnitude of y.
#
# Finally, let's look at a mini example of system characterization.  Suppose you have a system that smooths the signal by taking a moving average of adjacent elements:

# %%
window = numpy.array([0.5, 0.5, 0, 0, 0, 0, 0, 0,])

# %% [markdown]
# For this moving average window, we can compute the transfer function:

# %%
filtr = scipy.fftpack.fft(window)
filtr

# %% [markdown]
# Here are the magnitudes:

# %%
numpy.absolute(filtr)

# %% [markdown]
# To visualize the transfer function, I'll roll it so that frequency 0 is in the middle.  The DFT of a smoothing window is approximately Gaussian:

# %%
rolled = numpy.roll(filtr, 3)
thinkplot.plot([-3, -2, -1, 0, 1, 2, 3, 4], rolled.real)

# %% [markdown]
# If you multiply the transfer function by the spectrum of an impulse (which is all ones), the result is the filter:

# %%
product = spectrum * filtr
print(product)

# %% [markdown]
# Now if you transform back to the time domain, you have the impulse response, which looks a lot like the window:

# %%
filtered = scipy.fftpack.ifft(product)
thinkplot.plot(filtered.real)

# %%
print(filtered.real)

# %% [markdown]
# This example is meant to demonstrate why a recording of an impulse response is sufficient to characterize a system: because it is the IDFT of the transfer function.
